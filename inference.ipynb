# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Mon Jun 10 09:52:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/BoT-SORT/MCMOT/
# %ls
# Out:
# /content/gdrive/MyDrive/BoT-SORT/MCMOT
# fast_reid/       Miniconda3-latest-Linux-x86_64.sh  setup.cfg  tracker/                yolov7/
# inference.ipynb  py-lap/                            setup.py   ultralytics/            yolov8/
# logs/            requirements.txt                   tools/     VideoCameraCorrection/

# %%
# !pip install numpy
# !pip install -r /content/gdrive/MyDrive/BoT-SORT/MCMOT/requirements.txt
# !pip install lap
# !pip install cython
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install cython_bbox
# !pip install faiss-cpu
# !pip install faiss-gpu
# !pip install ultralytics
# !pip install lap
# !pip install yacs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 23.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 77.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 108.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 95.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %% [markdown]
# ## Inference

# %%
# !bash /content/gdrive/MyDrive/BoT-SORT/MCMOT/tools/track_all_timestamps_v8.sh --weights /content/gdrive/MyDrive/BoT-SORT/MCMOT/ultralytics/runs/detect/train/weights/best.pt --source-dir /content/gdrive/MyDrive/BoT-SORT/AI_CUP_testdata/images --device "0" --fast-reid-config /content/gdrive/MyDrive/BoT-SORT/MCMOT/logs/bagtricks_R50-ibn_256_v2/config.yaml --fast-reid-weights /content/gdrive/MyDrive/BoT-SORT/MCMOT/logs/bagtricks_R50-ibn_256_v2/model_0058.pth
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 736x1280 1 car, 125.7ms
# Speed: 3.3ms preprocess, 125.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
# tracking 1001_180000_181558:  61% 887/1447 [05:44<01:59,  4.68it/s]
# 0: 736x1280 3 cars, 125.1ms
# Speed: 3.7ms preprocess, 125.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
# tracking 1001_180000_181558:  61% 888/1447 [05:44<02:02,  4.56it/s]
# 0: 736x1280 3 cars, 126.2ms
# Speed: 3.2ms preprocess, 126.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
# tracking 1001_180000_181558:  61% 889/1447 [05:44<02:06,  4.41it/s]
# 0: 736x1280 3 cars, 127.2ms
# Speed: 3.3ms preprocess, 127.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
# tracking 1001_180000_181558:  62% 890/1447 [05:45<02:13,  4.16it/s]
# 0: 736x1280 4 cars, 123.5ms
# Speed: 3.3ms preprocess, 123.5ms inference, 3.4ms postprocess per image at shape (1, 3, 736, 1280)
# ...
